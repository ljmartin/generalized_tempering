# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('methane.dat', sep='\t')

# %%
for col in df.columns[5:]:
    plt.plot(df[col])
    
#plt.yscale('symlog')

# %%
df
# Out:
#         Steps  weightUpdate  Level  PotentialEnergy  1 Weight  0.75 Weight  \
# 0      101000      1.000000  0.000         -12469.5         0      0.00000
# 1      102000      1.000000  0.000         -12509.0         0      0.00000
# 2      103000      1.000000  0.000         -12483.6         0      0.00000
# 3      104000      1.000000  0.000         -12544.7         0      0.00000
# 4      105000      1.000000  0.001         -12395.1         0      0.00000
# ...       ...           ...    ...              ...       ...          ...
# 4912  5013000      0.001953  0.000         -12294.2         0      1.28711
# 4913  5014000      0.001953  0.000         -12419.1         0      1.28711
# 4914  5015000      0.001953  0.000         -12348.5         0      1.28711
# 4915  5016000      0.000977  0.000         -12339.0         0      1.28711
# 4916  5017000      0.000977  0.000         -12238.6         0      1.28711
#
# ...

# %%
plt.plot(df['Level'])

# %%
plt.plot(df['weightUpdate'])
plt.yscale('log')

# %%
df.groupby('Level')['PotentialEnergy'].plot(kind='kde')
# Out:
# Level
# 0.000    AxesSubplot(0.125,0.125;0.775x0.755)
# 0.001    AxesSubplot(0.125,0.125;0.775x0.755)
# 0.005    AxesSubplot(0.125,0.125;0.775x0.755)
# 0.010    AxesSubplot(0.125,0.125;0.775x0.755)
# 0.050    AxesSubplot(0.125,0.125;0.775x0.755)
# 0.100    AxesSubplot(0.125,0.125;0.775x0.755)
# 0.300    AxesSubplot(0.125,0.125;0.775x0.755)
# 0.500    AxesSubplot(0.125,0.125;0.775x0.755)
# 0.750    AxesSubplot(0.125,0.125;0.775x0.755)
# 1.000    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: PotentialEnergy, dtype: object
